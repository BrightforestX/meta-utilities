# %% [markdown]
# # 04 Uplift (PyMC stub)
# Guardrail notebook for P1. If PyMC not installed, this cell documents the requirement.

# %%
try:
    import pymc as pm
    print('PyMC available, posterior sampling would go here.')
except Exception as e:
    print('PyMC not installed (optional). Notebook is a guardrail stub:', e)
